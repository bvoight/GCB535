# %% [markdown]
# ### ML 5 Prelab
#
# This prelab is really short -- First, pick a code name that you expect nobody else would pick. This is something that people in the class will be able to see (it might even be your own name - up to you).

# %% [markdown]
# _Q1: Your code name is:_

# %% [markdown]
# _Q2: Next, fill out [this form](https://goo.gl/forms/8wGUYb74YKiNXlOR2). Let us know how accurate you think your classifier will be on unseen data!_
